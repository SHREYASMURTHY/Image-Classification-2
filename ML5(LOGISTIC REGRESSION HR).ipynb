# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.github.com/codebasics/py/master/ML/7_logistic_reg/Exercise/HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.drop("Department",axis=1,inplace=True)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df=pd.get_dummies(df,'salary')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
corr_matrix = df.corr()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
# salary_high                      0.029708        -0.020628       -0.008726
# salary_low                      -0.047415         0.005221       -0.002504
# salary_medium                    0.031367         0.006191        0.007377
#
#                        average_montly_hours  time_spend_company  \
# ...

# %%
from sklearn.model_selection import train_test_split
x=df[['satisfaction_level','time_spend_company','Work_accident','salary_high','salary_low','salary_medium']]
y=df['left']
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=56)

# %%
train_x
# Out:
#        satisfaction_level  time_spend_company  Work_accident  salary_high  \
# 4474                 0.98                   3              0        False
# 767                  0.44                   3              0        False
# 13456                0.48                   2              0        False
# 2082                 0.33                   3              0        False
# 5573                 0.17                   5              0        False
# ...                   ...                 ...            ...          ...
# 9451                 0.96                   3              0        False
# 13730                0.45                  10              0        False
# 3264                 0.59                   2              0        False
# 399                  0.10                   4              0        False
# 2532                 0.75                   3              0        False
#
#        salary_low  salary_medium
# 4474        False           True
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(test_x)

# %%
lr.score(test_x,test_y)
# Out:
# 0.762

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test_y, pred)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.762
