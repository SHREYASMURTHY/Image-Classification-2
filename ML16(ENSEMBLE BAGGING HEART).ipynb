# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df=pd.read_csv("heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
numerical=df.select_dtypes(include=[np.number])
categorical=df.select_dtypes(exclude=[np.number])
z_scores=np.abs(stats.zscore(numerical))
thres=3
filtered=(z_scores<thres).all(axis=1)
numerical_filtered=numerical[filtered]
df_new=pd.concat([numerical_filtered,categorical[filtered]],axis=1)
df_new
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease Sex  \
# 0     40        140          289          0    172      0.0             0   M
# 1     49        160          180          0    156      1.0             1   F
# 2     37        130          283          0     98      0.0             0   M
# 3     48        138          214          0    108      1.5             1   F
# 4     54        150          195          0    122      0.0             0   M
# ..   ...        ...          ...        ...    ...      ...           ...  ..
# 913   45        110          264          0    132      1.2             1   M
# 914   68        144          193          1    141      3.4             1   M
# 915   57        130          131          0    115      1.2             1   M
# 916   57        130          236          0    174      0.0             1   F
# 917   38        138          175          0    173      0.0             0   M
#
# ...

# %%
#find ordinal
#since the below features are ordinal we can apply label encoder or just do what we did below

df_new.ExerciseAngina.replace(
    {
        'N': 0,
        'Y': 1
    },
    inplace=True)

df_new.ST_Slope.replace(
    {
        'Down': 1,
        'Flat': 2,
        'Up': 3
    },
    inplace=True
)

df_new.RestingECG.replace(
    {
        'Normal': 1,
        'ST': 2,
        'LVH': 3
    },
    inplace=True)

df_new.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease Sex  \
# 0   40        140          289          0    172      0.0             0   M
# 1   49        160          180          0    156      1.0             1   F
# 2   37        130          283          0     98      0.0             0   M
# 3   48        138          214          0    108      1.5             1   F
# 4   54        150          195          0    122      0.0             0   M
#
#   ChestPainType  RestingECG  ExerciseAngina  ST_Slope
# 0           ATA           1               0         3
# 1           NAP           1               0         2
# 2           ATA           2               0         3
# 3           ASY           1               1         2
# 4           NAP           1               0         3

# %%
#now use get_dummies for nominal
df1=pd.get_dummies(df_new,dtype=int)
df1
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      RestingECG  ExerciseAngina  ST_Slope  Sex_F  Sex_M  ChestPainType_ASY  \
# ...

# %%
df1.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  899.000000  899.000000   899.000000  899.000000  899.000000
# mean    53.497219  132.027809   198.005562    0.232481  136.917686
# std      9.456073   17.120895   107.157779    0.422649   25.356740
# min     28.000000   80.000000     0.000000    0.000000   63.000000
# 25%     47.000000  120.000000   174.500000    0.000000  120.000000
# 50%     54.000000  130.000000   222.000000    0.000000  138.000000
# 75%     60.000000  140.000000   266.000000    0.000000  156.000000
# max     77.000000  185.000000   518.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease  RestingECG  ExerciseAngina    ST_Slope  \
# count  899.000000    899.000000  899.000000      899.000000  899.000000
# mean     0.861513      0.547275    1.598443        0.403782    2.373749
# std      1.007626      0.498037    0.803693        0.490928    0.601057
# min     -2.000000      0.000000    1.000000        0.000000    1.000000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
x,y=df1.drop('HeartDisease',axis=1),df1.HeartDisease
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.24489796, 0.57142857, 0.55791506, ..., 1.        , 0.        ,
#         0.        ],
#        [0.42857143, 0.76190476, 0.34749035, ..., 0.        , 1.        ,
#         0.        ],
#        [0.18367347, 0.47619048, 0.54633205, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.59183673, 0.47619048, 0.25289575, ..., 0.        , 0.        ,
#         0.        ],
#        [0.59183673, 0.47619048, 0.45559846, ..., 1.        , 0.        ,
#         0.        ],
#        [0.20408163, 0.55238095, 0.33783784, ..., 0.        , 1.        ,
#         0.        ]])

# %%
from sklearn.model_selection import train_test_split
train_x_scaled,test_x_scaled,train_y,test_y=train_test_split(x_scaled,y,test_size=0.3,random_state=56)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(train_x_scaled,train_y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(test_x_scaled,test_y)
# Out:
# 0.8074074074074075

# %%
#with bagging
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
n_estimators=100,
    max_samples=0.8,
    oob_score=True,
    random_state=56)
bag_model.fit(train_x_scaled,train_y)
bag_model.oob_score_
# Out:
# 0.834658187599364

# %%
bag_model.score(test_x_scaled,test_y)
# Out:
# 0.8925925925925926
